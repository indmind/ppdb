# %%
from matplotlib import pyplot as plt
import json
import datetime

# %%
with open("data.json", "r") as f:
    data = json.loads(f.read())

# %%
nilai = [d["Nilai UN"] for d in data]

# %%
plt.plot(range(1, len(nilai)+ 1), nilai)

# %%
# Out:
# -------------------------------------------------------------
# TypeError                   Traceback (most recent call last)
# <ipython-input-28-f4d8e6e95fed> in <module>()
# ----> 1 datetime.time('2018-06-25 18:34:24')
#
# TypeError: an integer is required (got type str)

# %%
plt.plo
